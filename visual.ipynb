# 29        1.429418e+07        8896.591782     2.573337e+08
# 30        1.729265e+05      172926.493546     1.729265e+05
# 31        1.324661e+04        5115.274390     2.598801e+08
# 32        3.052729e+04        5443.339528     2.354685e+08
# 33        4.775399e+04        5884.866586     2.595332e+08
# 34        2.824912e+04        6185.867675     2.601056e+08
# 35        3.904318e+04        6843.209414     2.594860e+08
# 36        5.177866e+04        6724.009865     2.593744e+08
# 37        1.069592e+06        6881.797003     2.601285e+08
# 38        1.816156e+05        7437.886213     2.594291e+08
# 39        3.479828e+07        8613.956721     2.593166e+08

# %%
width = 20
height = 10
plt.figure(figsize=(width, height))

fg1 = plt.subplot(3,4,1)
fg1.set_title('Standard')
plt.plot(df_l['Standard'], color='red')

fg5 = plt.subplot(3,4,5)
fg5.set_title('Standard_GSS')
plt.plot( range(0, df_l.count()['Standard']), df_l['Standard_GSS'], color='red')

maximum = df_l['Standard'].max() if df_l['Standard'].max() > df_l['Standard_GSS'].max() else df_l['Standard_GSS'].max()

fg9 = plt.subplot(3,4,9)
fg9.set_title('Standard(Blue) / Standard_GSS(Green)')
fg9.set_ylim([0, 0.1])
plt.plot(range(0,df_l.count()['Standard']), df_l['Standard']/maximum,
         range(0,df_l.count()['Standard']), df_l['Standard_GSS']/maximum)

fg2 = plt.subplot(3,4,2)
fg2.set_title('Threshold')
plt.plot(df_l['Threshold'])

fg6 = plt.subplot(3,4,6)
fg6.set_title('Threshold_GSS')
plt.plot(df_l['Threshold_GSS']) 

maximum = df_l['Threshold'].max() if df_l['Threshold'].max() > df_l['Threshold_GSS'].max() else df_l['Threshold_GSS'].max()

fg10 = plt.subplot(3,4,10)
fg10.set_title('Threshold(Blue) / Threshold_GSS(Green)')
fg10.set_ylim([0, 0.4])
plt.plot(range(0,df_l.count()['Threshold']), df_l['Threshold']/maximum,
         range(0,df_l.count()['Threshold']), df_l['Threshold_GSS']/maximum)

fg3 = plt.subplot(3,4,3)
plt.plot(df_l['FaultInjection'], color='green')
fg3.set_title('Fault Injection')

fg7 = plt.subplot(3,4,7)
plt.plot(df_l['FaultInjection_GSS'], color='green')
fg7.set_title('Fault Injection GSS')

maximum = df_l['FaultInjection'].max() if df_l['FaultInjection'].max() > df_l['FaultInjection_GSS'].max() else df_l['FaultInjection_GSS'].max()

fg11 = plt.subplot(3,4,11)
fg11.set_title('FaultInjection(Blue) / FaultInjection_GSS(Green)')
fg11.set_ylim([0, 0.05])
plt.plot(range(0,df_l.count()['FaultInjection']), df_l['FaultInjection']/maximum,
         range(0,df_l.count()['FaultInjection']), df_l['FaultInjection_GSS']/maximum)

fg4 = plt.subplot(3,4,4)
plt.plot(df_l['NoiseInjetion'], color='purple')
fg4.set_title('Noise Injection')

fg8 = plt.subplot(3,4,8)
plt.plot(df_l['NoiseInjetion_GSS'], color='purple')
fg8.set_title('Noise Injection GSS')

maximum = df_l['NoiseInjetion'].max() if df_l['NoiseInjetion'].max() > df_l['NoiseInjetion_GSS'].max() else df_l['NoiseInjetion_GSS'].max()

fg12 = plt.subplot(3,4,12)
fg12.set_title('NoiseInjetion(Blue) / NoiseInjetion_GSS(Green)')
fg12.set_ylim([0, 0.05])
plt.plot(range(0,df_l.count()['NoiseInjetion']), df_l['NoiseInjetion']/maximum,
         range(0,df_l.count()['NoiseInjetion']), df_l['NoiseInjetion_GSS']/maximum)
# Out:
# [<matplotlib.lines.Line2D at 0xa39e52f5c0>,
#  <matplotlib.lines.Line2D at 0xa39e52fe48>]

# %%
width = 20
height = 10
plt.figure(figsize=(width, height))

fg1 = plt.subplot(1,3,1)
fg1.set_title('NeuralField')
fg1.plot(df_l['NeuralField'], color='red')

fg2 = plt.subplot(1,3,2)
fg2.set_title('NeuralField_GSS')
fg2.plot(df_l['NeuralField_GSS'])

maximum = df_l['NeuralField'].max() if df_l['NeuralField'].max() > df_l['NeuralField_GSS'].max() else df_l['NeuralField_GSS'].max()

fg3 = plt.subplot(1,3,3)
fg3.set_title('NeuralField(Blue) / NeuralField_GSS(Green)')
plt.plot(range(0,df_l.count()['NeuralField']), df_l['NeuralField']/maximum,
         range(0,df_l.count()['NeuralField']), df_l['NeuralField_GSS']/maximum)
# Out:
# [<matplotlib.lines.Line2D at 0xa39fb897f0>,
#  <matplotlib.lines.Line2D at 0xa39fb89f98>]

# %%
df_t = pd.read_csv('test_during_learn.txt', sep=';')

# %%
df_t
# Out:
#     Map_number  Epoch_number      Standard     Threshold  FaultInjection  \
# 0            0             0  45008.904297  45008.904297    45008.904297
# 1            0             1   6583.413086  13162.330078    10300.243164
# 2            0             2   6876.833008  13219.812500     8713.854492
# 3            0             3   4981.070313  10594.583984     8043.104492
# 4            0             4   5286.500977  11851.767578     7018.993164
# 5            0             5   3574.264648   9516.413086     4790.845703
# 6            0             6   2703.082031   7965.738281     5167.430664
# 7            0             7   2546.864258   7803.560547     5766.690430
# 8            0             8   2178.037109   7083.056641    14212.809570
# 9            0             9   2054.796875   6832.913086    41965.536133
# 10           1             0  87131.736328  87131.736328    87131.736328
# 11           1             1   7163.979492   9546.930664    10529.925781
# 12           1             2   5517.870117  10497.433594     6932.630859
# 13           1             3   4662.419922   9362.451172     4829.502930
# 14           1             4   4089.177734   9508.885742     8607.911133
# 15           1             5   3538.113281   9114.031250     7270.416992
# 16           1             6   3184.630859   8216.630859     6214.220703
# 17           1             7   2520.181641   7466.724609     6712.171875
# 18           1             8   2124.217773   6838.447266    11185.484375
# 19           1             9   1999.743164   6732.591797    26760.789063
# 20           2             0  34745.342773  34745.342773    34745.342773
# 21           2             1   8184.733398  10077.547852    10231.760742
# 22           2             2   5570.340820  11366.601563     8543.446289
# 23           2             3   5446.284180  10423.231445     7155.060547
# 24           2             4   4504.659180   8250.628906     5823.224609
# 25           2             5   3233.323242   7627.291016     5755.230469
# 26           2             6   3158.256836   7331.633789     4810.255859
# 27           2             7   2575.767578   6763.260742     7055.610352
# 28           2             8   2163.896484   5786.298828     9350.468750
# 29           2             9   1934.601563   5091.875977    21379.828125
# 30           3             0  42005.039063  42005.039063    42005.039063
# 31           3             1   5833.419922   9388.194336     7139.894531
# 32           3             2   5934.089844   9520.641602     6917.027344
# 33           3             3   5410.930664   9145.176758     6944.547852
# 34           3             4   3756.204102   8832.261719     4949.803711
# 35           3             5   3274.158203   7818.190430     4919.293945
# 36           3             6   2980.250977   7370.700195     5961.335938
# 37           3             7   2590.381836   7049.061523     6582.135742
# 11        2.449108e+04        5090.383630     2.561689e+08
# 12        1.790751e+04        5619.602239     2.548746e+08
# 13        2.001976e+04        5687.923357     2.562028e+08
# 14        6.010982e+04        5455.947680     2.559159e+08
# 15        1.241350e+05        5753.760538     2.567903e+08
# 16        4.154735e+04       11936.881100     2.568281e+08
# 17        4.260840e+05       11895.793041     2.563215e+08
# 18        2.166584e+06       13904.060502     2.560228e+08
# 19        1.936669e+07       15105.324830     2.579471e+08
# 20        2.287392e+05      228739.179291     2.287392e+05
# 21        1.976079e+04        5716.694295     2.574503e+08
# 22        2.399595e+04        5310.255988     2.567435e+08
# 23        2.701556e+04        5547.281034     2.573164e+08
# 24        3.798241e+04        5541.683483     2.572541e+08
# 25        4.398521e+04        6183.077167     2.584153e+08
# 26        1.176107e+05        6432.253052     2.582922e+08
# 27        7.316886e+05        7297.489410     2.572664e+08
# 28        8.416286e+05        7914.099508     2.356763e+08
# 29        1.429546e+07        8720.868153     2.573096e+08
# 30        1.722760e+05      172276.045219     1.722760e+05
# 31        1.351238e+04        5362.179769     2.599113e+08
# 32        3.126044e+04        5412.534648     2.354211e+08
# 33        4.715940e+04        5674.897033     2.594550e+08
# 34        2.712220e+04        6077.817360     2.600528e+08
# 35        3.972399e+04        6848.346936     2.594851e+08
# 36        4.994662e+04        6551.228001     2.593684e+08
# 37        1.068449e+06        6893.229103     2.600072e+08
# 38        1.830787e+05        7512.808529     2.593684e+08
# 39        3.478740e+07        8590.634725     2.592858e+08

# %%
width = 20
height = 10
plt.figure(figsize=(width, height))

fg1 = plt.subplot(3,4,1)
fg1.set_title('Standard')
plt.plot(df_t['Standard'], color='red')

fg5 = plt.subplot(3,4,5)
fg5.set_title('Standard_GSS')
plt.plot( range(0, df_t.count()['Standard']), df_t['Standard_GSS'], color='red')

maximum = df_t['Standard'].max() if df_t['Standard'].max() > df_t['Standard_GSS'].max() else df_t['Standard_GSS'].max()

fg9 = plt.subplot(3,4,9)
fg9.set_title('Standard(Blue) / Standard_GSS(Green)')
fg9.set_ylim([0, 0.05])
plt.plot(range(0,df_t.count()['Standard']), df_t['Standard']/maximum,
         range(0,df_t.count()['Standard']), df_t['Standard_GSS']/maximum)

fg2 = plt.subplot(3,4,2)
fg2.set_title('Threshold')
plt.plot(df_t['Threshold'])

fg6 = plt.subplot(3,4,6)
fg6.set_title('Threshold_GSS')
plt.plot(df_t['Threshold_GSS']) 

maximum = df_t['Threshold'].max() if df_t['Threshold'].max() > df_t['Threshold_GSS'].max() else df_t['Threshold_GSS'].max()

fg10 = plt.subplot(3,4,10)
fg10.set_title('Threshold(Blue) / Threshold_GSS(Green)')
fg10.set_ylim([0, 0.4])
plt.plot(range(0,df_t.count()['Threshold']), df_t['Threshold']/maximum,
         range(0,df_t.count()['Threshold']), df_t['Threshold_GSS']/maximum)

fg3 = plt.subplot(3,4,3)
plt.plot(df_t['FaultInjection'], color='green')
fg3.set_title('Fault Injection')

fg7 = plt.subplot(3,4,7)
plt.plot(df_t['FaultInjection_GSS'], color='green')
fg7.set_title('Fault Injection GSS')

maximum = df_t['FaultInjection'].max() if df_t['FaultInjection'].max() > df_t['FaultInjection_GSS'].max() else df_t['FaultInjection_GSS'].max()

fg11 = plt.subplot(3,4,11)
fg11.set_title('FaultInjection(Blue) / FaultInjection_GSS(Green)')
fg11.set_ylim([0, 0.3])
plt.plot(range(0,df_t.count()['FaultInjection']), df_t['FaultInjection']/maximum,
         range(0,df_t.count()['FaultInjection']), df_t['FaultInjection_GSS']/maximum)

fg4 = plt.subplot(3,4,4)
plt.plot(df_t['NoiseInjetion'], color='purple')
fg4.set_title('Noise Injection')

fg8 = plt.subplot(3,4,8)
plt.plot(df_t['NoiseInjetion_GSS'], color='purple')
fg8.set_title('Noise Injection GSS')

maximum = df_t['NoiseInjetion'].max() if df_t['NoiseInjetion'].max() > df_t['NoiseInjetion_GSS'].max() else df_t['NoiseInjetion_GSS'].max()

fg12 = plt.subplot(3,4,12)
fg12.set_title('NoiseInjetion(Blue) / NoiseInjetion_GSS(Green)')
fg12.set_ylim([0, 0.05])
plt.plot(range(0,df_t.count()['NoiseInjetion']), df_t['NoiseInjetion']/maximum,
         range(0,df_t.count()['NoiseInjetion']), df_t['NoiseInjetion_GSS']/maximum)
# Out:
# [<matplotlib.lines.Line2D at 0xa3a1445940>,
#  <matplotlib.lines.Line2D at 0xa3a1445a20>]

# %%
width = 20
height = 10
plt.figure(figsize=(width, height))

fg1 = plt.subplot(1,3,1)
fg1.set_title('NeuralField')
fg1.plot(df_t['NeuralField'], color='red')

fg2 = plt.subplot(1,3,2)
fg2.set_title('NeuralField_GSS')
fg2.plot(df_t['NeuralField_GSS'])

maximum = df_t['NeuralField'].max() if df_t['NeuralField'].max() > df_t['NeuralField_GSS'].max() else df_t['NeuralField_GSS'].max()

fg3 = plt.subplot(1,3,3)
fg3.set_title('NeuralField(Blue) / NeuralField_GSS(Green)')
plt.plot(range(0,df_t.count()['NeuralField']), df_t['NeuralField']/maximum,
         range(0,df_t.count()['NeuralField']), df_t['NeuralField_GSS']/maximum)
# Out:
# [<matplotlib.lines.Line2D at 0xa3a081d550>,
#  <matplotlib.lines.Line2D at 0xa3a081d908>]

# %%
df_s = pd.read_csv('statistics.txt', sep=';')

# %%
df_s
# Out:
#    Percentage_faults  Standard_avg  Standard_std  Threshold_avg  \
# 0                  0   1942.849854     73.429794    6363.584229
# 1                  1   2535.633850    258.486694    7236.888367
# 2                  2   3456.227966    585.157227    8489.416931
# 3                  3   4065.270630    512.965637   11229.073364
# 4                  4   4971.456909    967.377258   11429.312317
# 5                  5   5403.928528    959.951538   14091.469788
# 6                  6   6823.468384   1071.927612   16827.305237
# 7                  7   8190.019348   2609.097412   16931.487854
# 8                  8  11951.155884   4298.949219   24058.845276
# 9                  9  12613.421509   3309.085449   23394.675110
#
#    Threshold_std  FaultInjection_avg  FaultInjection_std  \
# 0     818.250793        33407.626221         6633.560059
# 1    1113.072632        68859.437317        87405.843750
# 2    1969.706299        99131.487732       141107.484375
# 3    2221.942139        76581.925110        41531.917969
# 4    3252.745850        82770.809387        54121.777344
# 5    4134.818359       144424.283936       152020.609375
# 6    5499.038574       124031.504639        97112.609375
# 7    4348.797363       112603.098328        83560.335938
# 8    8066.219238       123984.675842        62933.812500
# 9    6956.030762       241308.153442       214516.062500
#
#        NoiseInjetion_avg  NoiseInjetion_std  NeuralField_avg  \
# 0            2511.068604         697.490906     1.031259e+09
# 1            3333.002808        1093.457642     7.837469e+08
# 2            4157.153931        1140.673828     5.468515e+08
# 3            5211.579407        1593.570068     4.750835e+08
# 4            6441.882446        1820.085693     4.244098e+08
# 5            7864.089172        2510.127441     3.729659e+08
# 6            9992.198364        5561.997070     3.496362e+08
# 7           10582.448730        3004.187744     3.748018e+08
# 8           15404.185181       10532.442383     3.067958e+08
# 9           14246.056030        4601.541504     2.896890e+08
#
#           ...           Standard_GSS_avg  Standard_GSS_std  Threshold_GSS_avg  \
# 0         ...               8.754376e+03      1.126352e+02       8.470474e+04
# 1         ...               3.223784e+04      2.633645e+04       1.383977e+05
# 2         ...               1.147729e+05      1.124644e+05       3.118181e+05
# 3         ...               2.719646e+05      2.213878e+05       5.992247e+05
# 4         ...               9.277170e+05      1.175151e+06       7.822448e+05
# 5         ...               1.122879e+06      1.131911e+06       1.596074e+06
# 6         ...               1.451127e+06      1.762814e+06       2.120763e+06
# 7         ...               2.719024e+06      3.150426e+06       3.564030e+06
# 8         ...               2.374378e+06      1.676645e+06       5.199869e+06
# 9         ...               5.266113e+06      4.760416e+06       1.153535e+07
#
#    Threshold_GSS_std      FaultInjection_GSS_avg  FaultInjection_GSS_std  \
# 0       1.172083e+04                4.981558e+07              17421984.0
# 1       5.967516e+04                4.918436e+07              15084859.0
# 2       2.400229e+05                5.604426e+07              21058788.0
# 3       6.774497e+05                6.191892e+07              23652212.0
# 4       5.944618e+05                7.114084e+07              23007342.0
# 5       1.199357e+06                7.472214e+07              25285632.0
# 6       1.654441e+06                6.807590e+07              23730618.0
# 7       2.382323e+06                8.919462e+07              35621340.0
# 8       4.016182e+06                8.300476e+07              43243772.0
# 9       9.938478e+06                1.070583e+08              28688320.0
#
#    NoiseInjetion_GSS_avg  NoiseInjetion_GSS_std  NeuralField_GSS_avg  \
# 0           1.399776e+04           5.676727e+03         2.581643e+08
# 1           5.163605e+04           3.608137e+04         2.516545e+08
# 2           2.021571e+05           2.023181e+05         2.515450e+08
# 3           3.079977e+05           2.099261e+05         2.437479e+08
# 4           7.451992e+05           8.935391e+05         2.445816e+08
# 5           1.350261e+06           9.400145e+05         2.393344e+08
# 6           3.609446e+06           5.063884e+06         2.502087e+08
# 7           3.504135e+06           3.502610e+06         2.678077e+08
# 8           5.294079e+06           6.629704e+06         2.221728e+08
# 9           8.306656e+06           7.481444e+06         2.767789e+08
#
#    NeuralField_GSS_std
# 0             928582.5
# 1           14379217.0
# 2           13651273.0
# 3           25013756.0
# 4           34244424.0
# 5           26077152.0
# 6           35101500.0
# 7           42657240.0
# 8           48824668.0
# 9           53668204.0
#
# [10 rows x 21 columns]

# %%
width = 20
height = 10
plt.figure(figsize=(width, height))

fg1 = plt.subplot(2,5,1)
fg1.set_xlim([-1, df_s.count()['Percentage_faults']])
fg1.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg1.set_title("Standard")
fg1.errorbar(range(0,df_s.count()['Standard_avg']), df_s['Standard_avg'], yerr=df_s['Standard_std'], fmt='-o')

fg2 = plt.subplot(2,5,2)
fg2.set_xlim([-1, df_s.count()['Percentage_faults']])
fg2.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg2.set_title("Threshold")
fg2.errorbar(range(0,df_s.count()['Threshold_avg']), df_s['Threshold_avg'], yerr=df_s['Threshold_std'], fmt='-o')

fg3 = plt.subplot(2,5,3)
fg3.set_xlim([-1, df_s.count()['Percentage_faults']])
fg3.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg3.set_title("FaultInjection")
fg3.errorbar(range(0,df_s.count()['FaultInjection_avg']), df_s['FaultInjection_avg'], yerr=df_s['FaultInjection_std'], fmt='-o')

fg4 = plt.subplot(2,5,4)
fg4.set_xlim([-1, df_s.count()['Percentage_faults']])
fg4.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg4.set_title("NoiseInjetion")
fg4.errorbar(range(0,df_s.count()['    NoiseInjetion_avg']), df_s['    NoiseInjetion_avg'], yerr=df_s['NoiseInjetion_std'], fmt='-o')

fg5 = plt.subplot(2,5,5)
fg5.set_xlim([-1, df_s.count()['Percentage_faults']])
fg5.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg5.set_title("NeuralField")
fg5.errorbar(range(0,df_s.count()['NeuralField_avg']), df_s['NeuralField_avg'], yerr=df_s['NeuralField_std'], fmt='-o')

fg6 = plt.subplot(2,5,6)
fg6.set_xlim([-1, df_s.count()['Percentage_faults']])
fg6.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg6.set_title("Standard_GSS")
fg6.errorbar(range(0,df_s.count()['Standard_GSS_avg']), df_s['Standard_GSS_avg'], yerr=df_s['Standard_GSS_std'], fmt='-o')

fg7 = plt.subplot(2,5,7)
fg7.set_xlim([-1, df_s.count()['Percentage_faults']])
fg7.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg7.set_title("Threshold_GSS")
fg7.errorbar(range(0,df_s.count()['Threshold_GSS_avg']), df_s['Threshold_GSS_avg'], yerr=df_s['Threshold_GSS_std'], fmt='-o')

fg8 = plt.subplot(2,5,8)
fg8.set_xlim([-1, df_s.count()['Percentage_faults']])
fg8.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg8.set_title("FaultInjection_GSS")
fg8.errorbar(range(0,df_s.count()['    FaultInjection_GSS_avg']), df_s['    FaultInjection_GSS_avg'], yerr=df_s['FaultInjection_GSS_std'], fmt='-o')

fg9 = plt.subplot(2,5,9)
fg9.set_xlim([-1, df_s.count()['Percentage_faults']])
fg9.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg9.set_title("NoiseInjetion_GSS")
fg9.errorbar(range(0,df_s.count()['NoiseInjetion_GSS_avg']), df_s['NoiseInjetion_GSS_avg'], yerr=df_s['NoiseInjetion_GSS_std'], fmt='-o')

fg10 = plt.subplot(2,5,10)
fg10.set_xlim([-1, df_s.count()['Percentage_faults']])
fg10.set_xticks(range(-1,df_s.count()['Percentage_faults']+1))
fg10.set_title("NeuralField_GSS")
fg10.errorbar(range(0,df_s.count()['NeuralField_GSS_avg']), df_s['NeuralField_GSS_avg'], yerr=df_s['NeuralField_GSS_std'], fmt='-o')
# Out:
# <Container object of 3 artists>
